# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pickle
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier   
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
dataset=pd.read_csv('sales_prep.csv',index_col=None)


dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)


indep_X=dataset[['Holiday_Season', 'Customer_Rating', 'Average_Transaction_Value','Weekend_Sales_Percentage', 'Marketing_Channel_TV']]
dep_Y=dataset[['Sales_Revenue']]

# %%
sd=StandardScaler()
indep_X=sd.fit_transform(indep_X)
sdy=StandardScaler()
dep_Y=sdy.fit_transform(dep_Y)
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'],'splitter':['best', 'random'],'max_features':['sqrt', 'log2']}
from sklearn.tree import DecisionTreeRegressor
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)
grid.fit(indep_X,dep_Y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
result=grid.cv_results_
print("Thte R_Score value for best parameter:{}".format(grid.best_params_))
table=pd.DataFrame.from_dict(result)
table
# Out:
# Thte R_Score value for best parameter:{'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005253      0.003250         0.000000        0.000000
# 1        0.002206      0.001886         0.000752        0.000925
# 2        0.000000      0.000000         0.002564        0.003301
# 3        0.002633      0.003478         0.000303        0.000607
# 4        0.001521      0.001918         0.002088        0.004176
# 5        0.003693      0.003872         0.006088        0.003881
# 6        0.003219      0.000620         0.001715        0.000381
# 7        0.002749      0.001371         0.001521        0.000463
# 8        0.017013      0.004399         0.000000        0.000000
# 9        0.009066      0.003800         0.001502        0.003004
# 10       0.018151      0.005688         0.000302        0.000604
# 11       0.006187      0.004348         0.002305        0.003899
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...          -0.814127
# 1   {'criterion': 'squared_error', 'max_features':...          -1.118691
# 2   {'criterion': 'squared_error', 'max_features':...          -0.828473
# 3   {'criterion': 'squared_error', 'max_features':...          -0.604638
# 4   {'criterion': 'friedman_mse', 'max_features': ...          -0.911674
# 5   {'criterion': 'friedman_mse', 'max_features': ...          -0.928442
# 6   {'criterion': 'friedman_mse', 'max_features': ...          -1.103232
# 7   {'criterion': 'friedman_mse', 'max_features': ...          -1.044646
# 8   {'criterion': 'absolute_error', 'max_features'...          -0.731099
# 9   {'criterion': 'absolute_error', 'max_features'...          -0.816662
# 10  {'criterion': 'absolute_error', 'max_features'...          -1.193931
# 11  {'criterion': 'absolute_error', 'max_features'...          -1.073192
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -1.359781          -0.607147          -0.851369
# 1           -1.187377          -0.969062          -0.831988
# 2           -0.947557          -0.829056          -1.335123
# 3           -1.037817          -0.895687          -0.946804
# 4           -1.070494          -0.954012          -0.898623
# 5           -1.302487          -0.950727          -0.780631
# 6           -1.207285          -1.010559          -0.974748
# 7           -1.211770          -0.789890          -1.145561
# 8           -1.298001          -1.271719          -0.861196
# 9           -0.988739          -0.992904          -0.924971
# 10          -0.890611          -0.944472          -0.783147
# 11          -1.234561          -1.130194          -0.954393
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.930391        -0.912563        0.247804                1
# 1           -1.070548        -1.035533        0.124134                8
# 2           -1.114826        -1.011007        0.193018                6
# 3           -1.428540        -0.982697        0.265933                3
# 4           -0.960760        -0.959112        0.060571                2
# 5           -1.052174        -1.002892        0.173118                5
# 6           -1.234035        -1.105972        0.102952               11
# 7           -1.262388        -1.090851        0.167184               10
# 8           -1.161750        -1.064753        0.227775                9
# 9           -1.402577        -1.025170        0.199158                7
# 10          -1.174195        -0.997271        0.161239                4
# 11          -1.310555        -1.140579        0.124128               12

# %%
y_predt=grid.predict(indep_X)
from sklearn.metrics import r2_score
r_score=r2_score(dep_Y,y_predt)
r_score
# Out:
# 1.0

# %%
filename="final_model_sales.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
Holiday_Season=int(input('Holiday Season Yes 1 or No 0:'))
Customer_Rating=float(input('Customer Rating:'))
Average_Transaction_Value=float(input('Average Transaction Value:'))
Weekend_Sales_Percentage=float(input('Weekend_Sales_Percentage:'))
Marketing_Channel_TV=int(input('Marketing Channel TV Yes 1 or No 0:'))
# Out:
# Holiday Season Yes 1 or No 0: 1
# Customer Rating:  3.908800318
# Average Transaction Value: 189.0082581
# Weekend_Sales_Percentage:  69.12508324
# Marketing Channel TV Yes 1 or No 0: 1

# %%
preinput=sd.transform([[Holiday_Season, Customer_Rating, Average_Transaction_Value, Weekend_Sales_Percentage, Marketing_Channel_TV]])
loaded_model=pickle.load(open("final_model_sales.sav",'rb'))
prediction_std=loaded_model.predict(preinput)
prediction=sdy.inverse_transform([prediction_std])
prediction
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[88959.0954761]])
