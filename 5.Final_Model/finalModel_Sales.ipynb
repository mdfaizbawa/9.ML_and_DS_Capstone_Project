# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pickle
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier   
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
dataset=pd.read_csv('sales_prep.csv',index_col=None)


dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)


indep_X=dataset[['Holiday_Season', 'Customer_Rating', 'Average_Transaction_Value','Weekend_Sales_Percentage', 'Marketing_Channel_TV']]
dep_Y=dataset[['Sales_Revenue']]

# %%
sd=StandardScaler()
indep_X=sd.fit_transform(indep_X)
sdy=StandardScaler()
dep_Y=sdy.fit_transform(dep_Y)
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'],'splitter':['best', 'random'],'max_features':['sqrt', 'log2']}
from sklearn.tree import DecisionTreeRegressor
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)
grid.fit(indep_X,dep_Y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
result=grid.cv_results_
print("Thte R_Score value for best parameter:{}".format(grid.best_params_))
table=pd.DataFrame.from_dict(result)
table
# Out:
# Thte R_Score value for best parameter:{'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.010255      0.001299         0.000803        0.001606
# 1        0.006040      0.005425         0.000926        0.001212
# 2        0.007314      0.004305         0.004294        0.005272
# 3        0.005252      0.003122         0.001525        0.001489
# 4        0.010240      0.002588         0.001472        0.001439
# 5        0.000000      0.000000         0.004492        0.004303
# 6        0.007136      0.003105         0.002176        0.002750
# 7        0.002876      0.001770         0.001265        0.001709
# 8        0.030769      0.008288         0.001001        0.001553
# 9        0.017811      0.007044         0.000418        0.000836
# 10       0.031845      0.007240         0.001524        0.003048
# 11       0.014314      0.004720         0.000000        0.000000
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...          -0.908971
# 1   {'criterion': 'squared_error', 'max_features':...          -0.891348
# 2   {'criterion': 'squared_error', 'max_features':...          -1.176348
# 3   {'criterion': 'squared_error', 'max_features':...          -1.058563
# 4   {'criterion': 'friedman_mse', 'max_features': ...          -1.036919
# 5   {'criterion': 'friedman_mse', 'max_features': ...          -1.146518
# 6   {'criterion': 'friedman_mse', 'max_features': ...          -0.741207
# 7   {'criterion': 'friedman_mse', 'max_features': ...          -0.832522
# 8   {'criterion': 'absolute_error', 'max_features'...          -1.079203
# 9   {'criterion': 'absolute_error', 'max_features'...          -1.079216
# 10  {'criterion': 'absolute_error', 'max_features'...          -1.059831
# 11  {'criterion': 'absolute_error', 'max_features'...          -1.045260
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -1.145833          -1.039369          -0.912434
# 1           -0.941283          -0.975325          -0.824152
# 2           -1.386642          -1.132383          -1.157251
# 3           -1.143646          -0.841870          -0.902004
# 4           -1.133285          -1.076185          -0.838544
# 5           -1.196397          -0.893409          -0.942129
# 6           -1.039962          -0.800187          -0.673700
# 7           -0.990552          -0.950516          -0.829518
# 8           -1.167829          -0.614754          -1.283405
# 9           -0.951629          -1.131422          -1.001861
# 10          -1.166505          -0.977600          -0.781304
# 11          -1.377168          -0.841242          -0.840059
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -1.577266        -1.116775        0.246506               11
# 1           -1.219461        -0.970314        0.134567                2
# 2           -0.994377        -1.169400        0.126011               12
# 3           -1.591063        -1.107429        0.264697               10
# 4           -1.291056        -1.075198        0.146588                7
# 5           -1.157769        -1.067244        0.124123                6
# 6           -1.183069        -0.887625        0.192531                1
# 7           -1.396434        -0.999908        0.208236                3
# 8           -1.278190        -1.084676        0.246865                8
# 9           -1.304161        -1.093657        0.122103                9
# 10          -1.258404        -1.048729        0.164033                5
# 11          -0.984923        -1.017730        0.196848                4

# %%
y_predt=grid.predict(indep_X)
from sklearn.metrics import r2_score
r_score=r2_score(dep_Y,y_predt)
r_score
# Out:
# 1.0

# %%
filename="final_model_sales.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
Holiday_Season=int(input('Holiday Season Yes 1 or No 0:'))
Customer_Rating=float(input('Customer Rating:'))
Average_Transaction_Value=float(input('Average Transaction Value:'))
Weekend_Sales_Percentage=float(input('Weekend_Sales_Percentage:'))
Marketing_Channel_TV=int(input('Marketing Channel TV Yes 1 or No 0:'))
# Out:
# Holiday Season Yes 1 or No 0: 1
# Customer Rating: 3.908800318
# Average Transaction Value: 189.0082581
# Weekend_Sales_Percentage: 69.12508324
# Marketing Channel TV Yes 1 or No 0: 1

# %%
preinput=sd.transform([[Holiday_Season, Customer_Rating, Average_Transaction_Value, Weekend_Sales_Percentage, Marketing_Channel_TV]])
loaded_model=pickle.load(open("final_model_sales.sav",'rb'))
prediction_std=loaded_model.predict(preinput)
prediction=sdy.inverse_transform([prediction_std])
prediction
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[179902.25099924]])
