# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

# %% [markdown]
# Data Collection

# %%
dataset=pd.read_csv('sales_revenu.csv',index_col=None)

dataset
# Out:
#      Store_ID  Product_ID Product_Category Store_Location Day_of_Week  \
# 0          52          27        Furniture          Rural    Saturday
# 1          93         177             Toys          Rural     Tuesday
# 2          15         161         Clothing       Suburban    Saturday
# 3          72          98          Grocery          Rural      Sunday
# 4          61         105             Toys       Suburban    Saturday
# ..        ...         ...              ...            ...         ...
# 795        26          17         Clothing          Rural     Tuesday
# 796        63          14          Grocery       Suburban      Friday
# 797        89         159      Electronics          Rural      Friday
# 798        86         152      Electronics          Urban    Thursday
# 799        59         108      Electronics          Urban      Sunday
#
#      Holiday_Season  Discount_Percentage  Advertising_Spend  Customer_Rating  \
# ...

# %% [markdown]
# Data Preprocessing

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Store_ID                        800 non-null    int64
#  1   Product_ID                      800 non-null    int64
#  2   Product_Category                800 non-null    object
#  3   Store_Location                  800 non-null    object
#  4   Day_of_Week                     800 non-null    object
#  5   Holiday_Season                  800 non-null    int64
#  6   Discount_Percentage             800 non-null    float64
#  7   Advertising_Spend               800 non-null    float64
#  8   Customer_Rating                 800 non-null    float64
#  9   Weather                         800 non-null    object
#  10  Number_of_Employees             800 non-null    int64
#  11  Store_Area_sqft                 800 non-null    int64
# ...

# %%
dataset.drop(['Store_ID','Product_ID','Day_of_Week'],axis=1,inplace=True)

# %%
dataset.isna().sum()
# Out:
# Product_Category                  0
# Store_Location                    0
# Holiday_Season                    0
# Discount_Percentage               0
# Advertising_Spend                 0
# Customer_Rating                   0
# Weather                           0
# Number_of_Employees               0
# Store_Area_sqft                   0
# Average_Transaction_Value         0
# Number_of_Customers               0
# Stock_Availability                0
# Competitor_Proximity_km           0
# Marketing_Channel                 0
# Operating_Hours_per_Week          0
# Store_Age_Years                   0
# Price_Sensitivity                 0
# Loyalty_Customers_Percentage      0
# Online_vs_Offline_Sales_Ratio     0
# Average_Product_Age_days          0
# Weekend_Sales_Percentage          0
# Regional_Economy_Index            0
# Store_Rent_Cost                   0
# Competitor_Discount_Percentage    0
# Local_Events                      0
# Monthly_Inventory_Cost            0
# ...

# %%
dataset.shape
# Out:
# (800, 27)

# %%
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Product_Category, Store_Location, Holiday_Season, Discount_Percentage, Advertising_Spend, Customer_Rating, Weather, Number_of_Employees, Store_Area_sqft, Average_Transaction_Value, Number_of_Customers, Stock_Availability, Competitor_Proximity_km, Marketing_Channel, Operating_Hours_per_Week, Store_Age_Years, Price_Sensitivity, Loyalty_Customers_Percentage, Online_vs_Offline_Sales_Ratio, Average_Product_Age_days, Weekend_Sales_Percentage, Regional_Economy_Index, Store_Rent_Cost, Competitor_Discount_Percentage, Local_Events, Monthly_Inventory_Cost, Sales_Revenue]
# Index: []
#
# [0 rows x 27 columns]

# %%
prep_df=dataset.copy()
prep_df.head()
# Out:
#   Product_Category Store_Location  Holiday_Season  Discount_Percentage  \
# 0        Furniture          Rural               1             8.605530
# 1             Toys          Rural               1            46.276110
# 2         Clothing       Suburban               0             3.416705
# 3          Grocery          Rural               0            21.518737
# 4             Toys       Suburban               1            34.789874
#
#    Advertising_Spend  Customer_Rating Weather  Number_of_Employees  \
# 0       13786.383758         3.544189   Rainy                   31
# 1       18833.572229         2.607173  Cloudy                   44
# 2        1412.323977         3.311312  Cloudy                   36
# 3        6733.215078         2.231497   Snowy                   30
# 4        9044.445975         2.908800   Snowy                   31
#
#    Store_Area_sqft  Average_Transaction_Value  ...  \
# 0             2458                 271.677695  ...
# ...

# %%
prep_df.to_csv("sales_prep.csv",index=False)
