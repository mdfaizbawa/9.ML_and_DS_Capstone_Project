# %%
import pandas as pd
from sklearn.model_selection import train_test_split 
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import pickle
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier   
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
dataset=pd.read_csv('sales_prep.csv',index_col=None)


dataset=pd.get_dummies(dataset,dtype=int, drop_first=True)


indep_X=dataset[['Holiday_Season', 'Customer_Rating', 'Average_Transaction_Value','Weekend_Sales_Percentage', 'Marketing_Channel_TV']]
dep_Y=dataset[['Sales_Revenue']]

# %%
sd=StandardScaler()
indep_X=sd.fit_transform(indep_X)
sdy=StandardScaler()
dep_Y=sdy.fit_transform(dep_Y)
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error'],'splitter':['best', 'random'],'max_features':['sqrt', 'log2']}
from sklearn.tree import DecisionTreeRegressor
grid=GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose=3,n_jobs=-1)
grid.fit(indep_X,dep_Y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
result=grid.cv_results_
print("Thte R_Score value for best parameter:{}".format(grid.best_params_))
table=pd.DataFrame.from_dict(result)
table
# Out:
# Thte R_Score value for best parameter:{'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.002750      0.002444         0.001931        0.002018
# 1        0.003914      0.002110         0.000273        0.000545
# 2        0.005296      0.001962         0.000583        0.000756
# 3        0.002214      0.001138         0.001395        0.000508
# 4        0.003080      0.001056         0.001204        0.000902
# 5        0.002196      0.001009         0.001812        0.000762
# 6        0.001970      0.000870         0.002031        0.000764
# 7        0.002255      0.000704         0.001289        0.000468
# 8        0.014507      0.003877         0.002214        0.002143
# 9        0.008313      0.002494         0.000863        0.001726
# 10       0.014848      0.002619         0.002913        0.002394
# 11       0.008435      0.001567         0.000922        0.001844
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...          -0.870517
# 1   {'criterion': 'squared_error', 'max_features':...          -0.746781
# 2   {'criterion': 'squared_error', 'max_features':...          -0.959477
# 3   {'criterion': 'squared_error', 'max_features':...          -0.940436
# 4   {'criterion': 'friedman_mse', 'max_features': ...          -1.161785
# 5   {'criterion': 'friedman_mse', 'max_features': ...          -0.860964
# 6   {'criterion': 'friedman_mse', 'max_features': ...          -0.802097
# 7   {'criterion': 'friedman_mse', 'max_features': ...          -0.629074
# 8   {'criterion': 'absolute_error', 'max_features'...          -1.096884
# 9   {'criterion': 'absolute_error', 'max_features'...          -0.949128
# 10  {'criterion': 'absolute_error', 'max_features'...          -0.820639
# 11  {'criterion': 'absolute_error', 'max_features'...          -0.946060
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -1.151903          -1.048722          -1.179477
# 1           -1.302163          -0.994259          -0.996180
# 2           -1.044509          -0.953995          -0.800263
# 3           -1.143390          -0.581163          -0.936728
# 4           -0.829495          -0.923887          -0.870939
# 5           -1.416653          -1.014487          -0.952909
# 6           -1.124717          -1.078639          -0.745259
# 7           -1.392088          -0.702199          -0.860285
# 8           -1.104163          -0.575846          -0.971177
# 9           -1.184891          -0.955345          -1.074153
# 10          -1.447339          -1.021543          -0.719744
# 11          -1.390297          -0.806164          -1.097981
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -1.136049        -1.077333        0.112279               11
# 1           -1.174412        -1.042759        0.188015                7
# 2           -1.228512        -0.997351        0.139869                4
# 3           -1.046313        -0.929606        0.190213                2
# 4           -1.477207        -1.052663        0.241477                9
# 5           -1.081166        -1.065236        0.190088               10
# 6           -1.278353        -1.005813        0.201548                6
# 7           -1.047134        -0.926156        0.273672                1
# 8           -1.039747        -0.957563        0.196748                3
# 9           -1.255208        -1.083745        0.121927               12
# 10          -0.992040        -1.000261        0.249541                5
# 11          -0.985237        -1.045148        0.196184                8

# %%
y_predt=grid.predict(indep_X)
from sklearn.metrics import r2_score
r_score=r2_score(dep_Y,y_predt)
r_score
# Out:
# 1.0

# %%
filename="final_model_sales.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
Holiday_Season=int(input('Holiday Season Yes 1 or No 0:'))
Customer_Rating=float(input('Customer Rating:'))
Average_Transaction_Value=float(input('Average Transaction Value:'))
Weekend_Sales_Percentage=float(input('Weekend_Sales_Percentage:'))
Marketing_Channel_TV=int(input('Marketing Channel TV Yes 1 or No 0:'))
# Out:
# Holiday Season Yes 1 or No 0: 1
# Customer Rating: 3.908800318
# Average Transaction Value: 189.0082581
# Weekend_Sales_Percentage: 69.12508324
# Marketing Channel TV Yes 1 or No 0: 1

# %%
preinput=sd.transform([[Holiday_Season, Customer_Rating, Average_Transaction_Value, Weekend_Sales_Percentage, Marketing_Channel_TV]])
loaded_model=pickle.load(open("final_model_sales.sav",'rb'))
prediction_std=loaded_model.predict(preinput)
prediction=sdy.inverse_transform([prediction_std])
prediction
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[170677.27571416]])
